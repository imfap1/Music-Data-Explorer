# %%
# Import necessary libraries
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Add the directory containing my custom modules to the Python path
import sys
sys.path.append("../src")

import function as func # Import functions.py
import spotify_utils  as spoti # Import spotify_utils.py

# %%
# final_df = spoti.get_spotify_data()

final_df = pd.read_csv('../data/playlist_country.csv')

# %%
# Displaying info
final_df
# Out:
#                                        Title  \
# 0                                Si No Estás
# 1                                   Lollipop
# 2                                PERRO NEGRO
# 3                                   El Mambo
# 4                                         OA
# ..                                       ...
# 245                                Kill Bill
# 246                            get him back!
# 247             (It Goes Like) Nanana - Edit
# 248                             Another Love
# 249  Rich Baby Daddy (feat. Sexyy Red & SZA)
#
#                                                Artist  \
# 0                                      iñigo quintero
# 1                                              Darell
# 2                                     Bad Bunny, Feid
# 3                                         Kiko Rivera
# 4    Anuel AA, Quevedo, Maluma, Mambo Kingz, DJ Luian
# ..                                                ...
# ...

# %%
file_path = '../images/'  # The folder where you want to save the image
file_name = 'piechart.png'  # The name of the image file

func.piechart(final_df, save=True, file_path=file_path, file_name=file_name)

# %%
func.top_popularity_songs(final_df)
# Out:
#             Title          Artist        Album Release Date  Popularity  \
# 0     Si No Estás  iñigo quintero  Si No Estás   2022-09-23          98
# 105        greedy      Tate McRae       greedy   2023-09-15          99
# 211  Cruel Summer    Taylor Swift        Lover   2019-08-23         100
# 152   Si No Estás  iñigo quintero  Si No Estás   2022-09-23          98
# 96   Cruel Summer    Taylor Swift        Lover   2019-08-23         100
#
#      Duration (s)  Explicit  Danceability  Energy    Tempo Country
# 0         184.061     False          53.7    42.1   98.224      ES
# 105       131.872      True          75.0    73.3  111.018      FR
# 211       178.426     False          55.2    70.2  169.994      GB
# 152       184.061     False          53.7    42.1   98.224      IT
# 96        178.426     False          55.2    70.2  169.994      PT

# %%
file_path = '../images/'  # The folder where you want to save the image
file_name = 'barplot.png'  # The name of the image file

func.barplot(final_df, save=True, file_path=file_path, file_name=file_name)

# %%
file_path = '../images/'  # The folder where you want to save the image
file_name = 'heatmap.png'  # The name of the image file

func.heatmap(final_df, save=True, file_path=file_path, file_name=file_name)

# %%
file_path = '../images/'  # The folder where you want to save the image
file_name = 'average_danceability.png'  # The name of the image file

func.average_danceability(final_df, save=True, file_path=file_path, file_name=file_name)

# %%
file_path = '../images/'  # The folder where you want to save the image
file_name = 'top_artists.png'  # The name of the image file

func.top_artist(final_df, save=True, file_path=file_path, file_name=file_name)

# %%
file_path = '../images/'  # The folder where you want to save the image
file_name = 'scatter_plot.png'  # The name of the image file

func.scatter_plot(final_df, save=True, file_path=file_path, file_name=file_name)
# Out:
# Overall Correlation: 0.01
# Correlations by Country:
# Country
# ES       Tempo   -0.207739
# FR       Tempo   -0.010582
# GB       Tempo    0.282296
# IT       Tempo   -0.133482
# PT       Tempo    0.062308
# Name: Energy, dtype: float64

# %%
file_path = '../images/'  # The folder where you want to save the image
file_name = 'average_song_duration.png'  # The name of the image file

average_durations = func.average_song(final_df, save=True, file_path=file_path, file_name=file_name)

# %%
folder_path = '../data/'
file_name = 'my_data.csv'

# Call the save_dataframe_to_csv function to save my DataFrame
success = func.save_dataframe_to_csv(final_df, folder_path, file_name)
